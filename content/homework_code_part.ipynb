# %%
# await __import__("piplite").install('openconmo', deps=False)
import numpy as np
import scipy
import tqdm
import matplotlib.pyplot as plt

from openconmo.benchmark_methods import envelope, DRS, benchmark_method
from data_imports import import_cwru_133, import_cwru_200

# %% [markdown]
# # Smith & Randall Benchmark Study (2015)
#
# Wade Smith and Robert Randall published a benchmark study in 2015 using methods described in these exercises. Please access and familiarize yourself with the publication content before beginning.
#
# ---
#
# ## Tasks
#
# 1.  **Replicate Results:**
#     Visualize **Figures 11 and 12** from the Smith and Randall article.
#     * **Parameters:** Use $N = 8192$ and $\Delta = 500$.
#     * *Note:* The resulting amplitudes may differ slightly from the original article.
# 2.  **Comparative Analysis:**
#     Describe the benefits and downsides of the following approaches:
#     * **Method 1:** Performing only envelope analysis.
#     * **Method 3:** Using Discrete Random Separation (DRS) and kurtogram.
#
# > **Note:** You are free to complete the exercise using any programming tools you prefer.
#
# ---
#
# ## Tips
#
# * **Data Sources:** Required data for Figures 11 and 12 is available in the notebook environment or can be downloaded via sources **200DE** and **133DE**.
# * **Ready-Made Functions:** DRS, kurtogram, and envelope methods are implemented in the **Aalto OpenConMo** repository.
# * **Workflow:** The simplest implementation path is using the coding environment from the **bearing fault tutorial** exercise session, as it contains the necessary data samples.
#
# ---
#
# ## Resource Links
#
# | Resource | Link |
# | :--- | :--- |
# | **Benchmark Publication** | [ResearchGate: Rolling Element Bearing Diagnostics](https://www.researchgate.net/publication/276248554_Rolling_Element_Bearing_Diagnostics_Using_the_Case_Western_Reserve_University_Data_A_Benchmark_Study) |
# | **Data Source (133.mat)** | [Case Western Reserve University - 133](https://engineering.case.edu/sites/default/files/133.mat) |
# | **Data Source (200.mat)** | [Case Western Reserve University - 200](https://engineering.case.edu/sites/default/files/200.mat) |
# | **OpenConMo Repo** | [GitHub: Aalto-Arotor/openConMo](https://github.com/Aalto-Arotor/openConMo) |
# | **Bearing Fault Tutorial** | [GitHub: Aalto-Arotor/bearing-fault-tutorial](https://github.com/Aalto-Arotor/bearing-fault-tutorial) |

# %%
# Use below lines to import sample data 133DE and 200DE from the cwru dataaset.
# signal133DE, fs, fr = import_cwru_133()
# signal200DE, fs, fr = import_cwru_200()

# %%
"""
Implement the tasks in the notebook here.

Include your results and answer to the questions in your report.
"""
